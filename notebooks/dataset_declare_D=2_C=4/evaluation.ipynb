# %%
import json
import pathlib

import pandas as pd

pd.set_option("max_colwidth", 400)

prefix = "dataset_declare_D=2_C=4"
separator = "_"
runs = [run for run in pathlib.Path("../../runs/").glob(f"{prefix}{separator}*")]
assert len(runs) == 5
for run in runs:
    print(run.name)
# Out:
# dataset_declare_D=2_C=4_f-01-nw-1000-ml-20-0
# dataset_declare_D=2_C=4_f-02-nw-1000-ml-20-0
# dataset_declare_D=2_C=4_f-03-nw-1000-ml-20-0
# dataset_declare_D=2_C=4_f-04-nw-1000-ml-20-0
# dataset_declare_D=2_C=4_f-05-nw-1000-ml-20-0

# %%
def evaluate(run):
    print(
        f"Evaluating models trained on",
        prefix,
        run.stem.removeprefix(prefix + separator),
    )
    models = [args.parent for args in run.rglob("args.json")]

    results_records = []
    for model in models:
        args = json.loads(model.joinpath("args.json").read_text())
        # print(args["constraints"])
        # print(args.get("constraints_multiplier", None))
        results = model.glob("**/results.json").__next__()
        # print(model.name)
        # print(results.read_text())
        results = json.loads(results.read_text())
        results_records.append(
            {
                "model": model.name,
                "constraints": args["constraints"],
                "constraints_multiplier": args.get("constraints_multiplier", None),
                "acc": results["acc"],
                "dld": results["dld"],
                "norm_dld": results["norm_dld"],
                "weighted_norm_dld": results["weighted_norm_dld"],
            }
        )

    df = pd.DataFrame(results_records, index=[r["model"] for r in results_records])
    df = df.drop(columns=["model"])
    df = df.sort_values(by="dld", ascending=True)
    display(df)

# %%
for run in runs:
    evaluate(run)
    print()
# Out:
# Evaluating models trained on dataset_declare_D=2_C=4 f-01-nw-1000-ml-20-0
#                                                                                                                                             constraints  \
# 20250316.2050.constraints                                                [Response[a, c], Absence2[c], Alternate Response[b, b], Not CoExistence[b, b]]
# 20250317.0928.constraints    [Alternate Precedence[c, b], Existence2[c], Alternate Succession[c, a], Not CoExistence[a, b], Not Chain Succession[c, b]]
# 20250316.1923.no_constraint                                                                                                                          []
# 20250316.1947.constraints    [Alternate Precedence[c, b], Existence2[c], Alternate Succession[c, a], Not CoExistence[a, b], Not Chain Succession[c, b]]
# 20250316.1930.constraints                               [Not Succession[a, a], Not Chain Succession[c, c], Not Succession[a, c], Not CoExistence[c, a]]
# 20250317.2007.constraints                               [Not Succession[a, a], Not Chain Succession[c, c], Not Succession[a, c], Not CoExistence[c, a]]
# 20250316.2039.constraints                              [Not Chain Succession[a, b], Not Chain Succession[a, a], Succession[c, c], Chain Response[c, b]]
# 20250317.0912.constraints                               [Not Succession[a, a], Not Chain Succession[c, c], Not Succession[a, c], Not CoExistence[c, a]]
# 20250317.1030.constraints                                                [Response[a, c], Absence2[c], Alternate Response[b, b], Not CoExistence[b, b]]
# 20250317.1020.constraints                              [Not Chain Succession[a, b], Not Chain Succession[a, a], Succession[c, c], Chain Response[c, b]]
# 20250317.2113.constraints                              [Not Chain Succession[a, b], Not Chain Succession[a, a], Succession[c, c], Chain Response[c, b]]
# 20250317.2022.constraints    [Alternate Precedence[c, b], Existence2[c], Alternate Succession[c, a], Not CoExistence[a, b], Not Chain Succession[c, b]]
# 20250317.2122.constraints                                                [Response[a, c], Absence2[c], Alternate Response[b, b], Not CoExistence[b, b]]
#
#                              constraints_multiplier       acc        dld  \
# 20250316.2050.constraints                      0.01  0.394709  15.936508
# 20250317.0928.constraints                      0.10  0.366138  16.666666
# 20250316.1923.no_constraint                     NaN  0.368254  16.984127
# 20250316.1947.constraints                      0.01  0.401058  17.047619
# 20250316.1930.constraints                      0.01  0.391534  17.174603
# 20250317.2007.constraints                      1.00  0.346561  17.777779
# 20250316.2039.constraints                      0.01  0.371429  17.873016
# 20250317.0912.constraints                      0.10  0.367725  18.111111
# 20250317.1030.constraints                      0.10  0.365608  19.000000
# 20250317.1020.constraints                      0.10  0.344974  19.634920
# 20250317.2113.constraints                      1.00  0.272487  21.666666
# 20250317.2022.constraints                      1.00  0.047619  28.571428
# 20250317.2122.constraints                      1.00  0.007407  29.777779
#
#                              norm_dld  weighted_norm_dld
# 20250316.2050.constraints    0.528923           0.531217
# 20250317.0928.constraints    0.554945           0.555556
# 20250316.1923.no_constraint  0.565896           0.566138
# 20250316.1947.constraints    0.569483           0.568254
# 20250316.1930.constraints    0.573336           0.572487
# 20250317.2007.constraints    0.595505           0.592593
# 20250316.2039.constraints    0.593445           0.595767
# 20250317.0912.constraints    0.604319           0.603704
# 20250317.1030.constraints    0.635417           0.633333
# 20250317.1020.constraints    0.655487           0.654497
# 20250317.2113.constraints    0.723558           0.722222
# 20250317.2022.constraints    0.952381           0.952381
# 20250317.2122.constraints    0.992483           0.992593
# Evaluating models trained on dataset_declare_D=2_C=4 f-02-nw-1000-ml-20-0
#                                                                                                                                             constraints  \
# 20250316.1924.no_constraint                                                                                                                          []
# 20250317.0007.constraints                                                [Response[a, c], Absence2[c], Alternate Response[b, b], Not CoExistence[b, b]]
# 20250316.2230.constraints    [Alternate Precedence[c, b], Existence2[c], Alternate Succession[c, a], Not CoExistence[a, b], Not Chain Succession[c, b]]
# 20250316.2215.constraints                               [Not Succession[a, a], Not Chain Succession[c, c], Not Succession[a, c], Not CoExistence[c, a]]
# 20250317.1143.constraints    [Alternate Precedence[c, b], Existence2[c], Alternate Succession[c, a], Not CoExistence[a, b], Not Chain Succession[c, b]]
# 20250317.2156.constraints                               [Not Succession[a, a], Not Chain Succession[c, c], Not Succession[a, c], Not CoExistence[c, a]]
# 20250316.2349.constraints                              [Not Chain Succession[a, b], Not Chain Succession[a, a], Succession[c, c], Chain Response[c, b]]
# 20250317.1128.constraints                               [Not Succession[a, a], Not Chain Succession[c, c], Not Succession[a, c], Not CoExistence[c, a]]
# 20250317.1245.constraints                                                [Response[a, c], Absence2[c], Alternate Response[b, b], Not CoExistence[b, b]]
# 20250317.1235.constraints                              [Not Chain Succession[a, b], Not Chain Succession[a, a], Succession[c, c], Chain Response[c, b]]
# 20250317.2309.constraints                              [Not Chain Succession[a, b], Not Chain Succession[a, a], Succession[c, c], Chain Response[c, b]]
# 20250317.2211.constraints    [Alternate Precedence[c, b], Existence2[c], Alternate Succession[c, a], Not CoExistence[a, b], Not Chain Succession[c, b]]
# 20250317.2319.constraints                                                [Response[a, c], Absence2[c], Alternate Response[b, b], Not CoExistence[b, b]]